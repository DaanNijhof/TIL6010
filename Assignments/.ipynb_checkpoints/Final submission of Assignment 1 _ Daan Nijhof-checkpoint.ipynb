# %% [markdown]
# ## General requirements for the assignment
# - Make appropriate comments to your code
# - Use Markdown cells to provide your answers (when applicable)
# - Add your code when there is the comment "YOUR CODE HERE".
# - Stick to Pep8 standard as much as possible for your coding
# - Submit through GitHub
# - Tag the commit as *Final submission of Assignment 1*
# - Post (interesting) errors in the course Github's issue page
#
# ## Assignment Intro
# In this assignment, you will be working with data imports. Data is provided to you both to be downloaded locally and accessed remotely. The final deliverable for the assignment is this ipython notebook with the executed cells active and submitted through your personal GitHub accounts. You will be importing data, conduct some basic data exploration and finally exporting the data and saving it for future use.
#
# You will be working with this data for the other two GO/NOGO assignments as well. The data is from the Google mobility report. You can find more information about this data here: <https://www.google.com/covid19/mobility/data_documentation.html?hl=en>.
#
# ### DEADLINE FOR THIS ASSIGNMENT IS 17 SEPTEMBER 2021 BEFORE 23:59
#
# <hr />

# %% [markdown]
# ## Import libraries
# Update this list as you go along with the assignment

# %%
import numpy as np
import pandas
import os

# import libraries

# %% [markdown]
# # PART I - Data Import and Export

# %% [markdown]
# #### 1. Download mobility data from this [link](https://www.google.com/covid19/mobility/), choose *Region CSVs*. From the downloaded data, pick a country to work with. Why did you choose this country?
#
# Picked the Netherlands, because I'm familiar with the dates changes may occur.

# %%
# path to the downloaded data folder, e.g. 'Downloads/Region_Mobility_Report_CSVs/'
data_dir = '/Users/Daan/Downloads/Region_Mobility_Report_CSVs/'
country_code = 'NL'

# %% [markdown]
# #### 2. Find the path to the data of your selection. We have prepared some sample code. You need to fill in some parts indicated by 'YOUR CODE HERE'.

# %%
all_files = os.listdir(data_dir)
# initilisation
target_file_name = ''
year = '2020'

for file_name in all_files:
    # check if this file is for 2020
    is_year = year
    # if yes, we check if the file name is for the country that you select
    if is_year:
        # check if the country_code is in the file_name
        is_country = country_code
        if is_country:
            # found the file, save it to 'target_file_name'
            # added stated year and country code to standard file name in directory
            target_file_name = '%s_%s_Region_Mobility_Report.csv' % (year, country_code)
            # we stop looking by breaking out of the for loop
            break

if not target_file_name:
    print('File not found. Check your country code (or select a different one)!')
else:
    print('Found file name is: ' + target_file_name)
    # get the path to the file
    file_path = '%s%s' % (data_dir, target_file_name)
    print('Path to the file is: ' + file_path)
# Out:
# Found file name is: 2020_NL_Region_Mobility_Report.csv
# Path to the file is: /Users/Daan/Downloads/Region_Mobility_Report_CSVs/2020_NL_Region_Mobility_Report.csv

# %% [markdown]
# #### 3. Import the 2020 data for this country as a pandas data frame and name it as `df_2020`. Print the first 10 lines of `df_2020`

# %%
# import and read .csv-file
df_2020 = pandas.read_csv(file_path)

df_2020.head(10)
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  NL    Netherlands          NaN          NaN         NaN
# 1                  NL    Netherlands          NaN          NaN         NaN
# 2                  NL    Netherlands          NaN          NaN         NaN
# 3                  NL    Netherlands          NaN          NaN         NaN
# 4                  NL    Netherlands          NaN          NaN         NaN
# 5                  NL    Netherlands          NaN          NaN         NaN
# 6                  NL    Netherlands          NaN          NaN         NaN
# 7                  NL    Netherlands          NaN          NaN         NaN
# 8                  NL    Netherlands          NaN          NaN         NaN
# 9                  NL    Netherlands          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-15
# 1             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-16
# 2             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-17
# 3             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-18
# 4             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-19
# 5             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-20
# 6             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-21
# 7             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-22
# 8             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-23
# 9             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-24
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                1.0
# 1                                              -10.0
# 2                                                0.0
# 3                                                5.0
# 4                                                3.0
# 5                                                1.0
# 6                                                8.0
# 7                                                1.0
# 8                                                1.0
# 9                                                9.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                1.0
# 1                                               -8.0
# 2                                               -1.0
# 3                                                4.0
# 4                                                0.0
# 5                                               -1.0
# 6                                                4.0
# 7                                               -2.0
# 8                                              -11.0
# 9                                               -7.0
#
#    parks_percent_change_from_baseline  \
# 0                                11.0
# 1                               -31.0
# 2                                 8.0
# 3                                21.0
# 4                                20.0
# 5                                -5.0
# 6                                22.0
# 7                                -2.0
# 8                               -26.0
# 9                                 4.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            3.0
# 1                                           -5.0
# 2                                           -3.0
# 3                                           -3.0
# 4                                           -3.0
# 5                                           -3.0
# 6                                            1.0
# 7                                           10.0
# 8                                            2.0
# 9                                           -4.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      0.0
# 1                                     -3.0
# 2                                     -5.0
# 3                                     -5.0
# 4                                     -5.0
# 5                                     -6.0
# 6                                     -9.0
# 7                                     -4.0
# 8                                     -3.0
# 9                                    -21.0
#
#    residential_percent_change_from_baseline
# 0                                       0.0
# 1                                       2.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
# 5                                       1.0
# 6                                       0.0
# 7                                       0.0
# 8                                       0.0
# 9                                       3.0

# %% [markdown]
# #### We have also stored the data in a remote server. The data for a particular country can be retrieved with the following API:
# `http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/{yy}/{CC}`
# #### where yy is either 2020 or 2021, and CC is a 2-letter country code. For example, to get data for 2020 for the Netherlands, the API will be: <http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/2020/NL>

# %% [markdown]
# #### 4. Download the mobility report data of **2021** for the same country (that you have chosen above) using this API and name it as `df_2021`.  Print the first 10 lines of the dataframe

# %%
# creating possibility of variable year and country
yy = '2021'
cc = country_code

# stating URL
URL_import = 'http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/%s/%s' % (yy, cc)

# import and read .csv-file
df_2021 = pandas.read_csv(URL_import)
df_2021.head(10)
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  NL    Netherlands          NaN          NaN         NaN
# 1                  NL    Netherlands          NaN          NaN         NaN
# 2                  NL    Netherlands          NaN          NaN         NaN
# 3                  NL    Netherlands          NaN          NaN         NaN
# 4                  NL    Netherlands          NaN          NaN         NaN
# 5                  NL    Netherlands          NaN          NaN         NaN
# 6                  NL    Netherlands          NaN          NaN         NaN
# 7                  NL    Netherlands          NaN          NaN         NaN
# 8                  NL    Netherlands          NaN          NaN         NaN
# 9                  NL    Netherlands          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-01
# 1             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-02
# 2             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-03
# 3             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-04
# 4             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-05
# 5             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-06
# 6             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-07
# 7             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-08
# 8             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-09
# 9             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-10
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                              -79.0
# 1                                              -65.0
# 2                                              -62.0
# 3                                              -52.0
# 4                                              -52.0
# 5                                              -53.0
# 6                                              -58.0
# 7                                              -55.0
# 8                                              -59.0
# 9                                              -60.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                              -77.0
# 1                                              -17.0
# 2                                              -19.0
# 3                                              -12.0
# 4                                               -8.0
# 5                                               -9.0
# 6                                              -15.0
# 7                                               -9.0
# 8                                               -9.0
# 9                                              -14.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 0.0
# 2                                 3.0
# 3                               -23.0
# 4                                -8.0
# 5                                -2.0
# 6                               -32.0
# 7                                 0.0
# 8                                19.0
# 9                                23.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                          -75.0
# 1                                          -59.0
# 2                                          -56.0
# 3                                          -62.0
# 4                                          -61.0
# 5                                          -58.0
# 6                                          -62.0
# 7                                          -57.0
# 8                                          -52.0
# 9                                          -52.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                    -83.0
# 1                                    -22.0
# 2                                    -12.0
# 3                                    -41.0
# 4                                    -41.0
# 5                                    -37.0
# 6                                    -39.0
# 7                                    -35.0
# 8                                    -12.0
# 9                                     -9.0
#
#    residential_percent_change_from_baseline
# 0                                      24.0
# 1                                      12.0
# 2                                       8.0
# 3                                      16.0
# 4                                      16.0
# 5                                      15.0
# 6                                      17.0
# 7                                      15.0
# 8                                      10.0
# 9                                       7.0

# %% [markdown]
# #### 5. Combine the two dataframes `df_2020` and `df_2021` into a new dataframe `df`. Print the last 10 lines of `df`.

# %%
# combine dataframes, ignoring index
df = pandas.concat([df_2020, df_2021], 
                   ignore_index=True)

df.tail(10)
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 198780                  NL    Netherlands      Zeeland        Veere
# 198781                  NL    Netherlands      Zeeland        Veere
# 198782                  NL    Netherlands      Zeeland        Veere
# 198783                  NL    Netherlands      Zeeland        Veere
# 198784                  NL    Netherlands      Zeeland        Veere
# 198785                  NL    Netherlands      Zeeland        Veere
# 198786                  NL    Netherlands      Zeeland        Veere
# 198787                  NL    Netherlands      Zeeland        Veere
# 198788                  NL    Netherlands      Zeeland        Veere
# 198789                  NL    Netherlands      Zeeland        Veere
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 198780         NaN             NaN               NaN
# 198781         NaN             NaN               NaN
# 198782         NaN             NaN               NaN
# 198783         NaN             NaN               NaN
# 198784         NaN             NaN               NaN
# 198785         NaN             NaN               NaN
# 198786         NaN             NaN               NaN
# 198787         NaN             NaN               NaN
# 198788         NaN             NaN               NaN
# 198789         NaN             NaN               NaN
#
#                            place_id        date  \
# 198780  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-23
# 198781  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-24
# 198782  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-25
# 198783  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-26
# 198784  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-27
# 198785  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-28
# 198786  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-29
# 198787  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-30
# 198788  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-31
# 198789  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-09-01
#
#         retail_and_recreation_percent_change_from_baseline  \
# 198780                                                NaN
# 198781                                                NaN
# 198782                                                NaN
# 198783                                                NaN
# 198784                                                NaN
# 198785                                                NaN
# 198786                                                NaN
# 198787                                                NaN
# 198788                                                NaN
# 198789                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 198780                                                NaN
# 198781                                                NaN
# 198782                                                NaN
# 198783                                                NaN
# 198784                                                NaN
# 198785                                                NaN
# 198786                                                NaN
# 198787                                                NaN
# 198788                                                NaN
# 198789                                                NaN
#
#         parks_percent_change_from_baseline  \
# 198780                                 NaN
# 198781                                 NaN
# 198782                                 NaN
# 198783                                 NaN
# 198784                                 NaN
# 198785                               311.0
# 198786                               237.0
# 198787                                 NaN
# 198788                                 NaN
# 198789                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 198780                                            NaN
# 198781                                            NaN
# 198782                                            NaN
# 198783                                            NaN
# 198784                                            NaN
# 198785                                            NaN
# 198786                                            NaN
# 198787                                            NaN
# 198788                                            NaN
# 198789                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 198780                                    -29.0
# 198781                                    -24.0
# 198782                                    -29.0
# 198783                                    -29.0
# 198784                                    -23.0
# 198785                                      NaN
# 198786                                      NaN
# 198787                                    -20.0
# 198788                                    -15.0
# 198789                                    -19.0
#
#         residential_percent_change_from_baseline
# 198780                                       4.0
# 198781                                       3.0
# 198782                                       4.0
# 198783                                       6.0
# 198784                                       3.0
# 198785                                       NaN
# 198786                                       NaN
# 198787                                       4.0
# 198788                                       3.0
# 198789                                       3.0

# %% [markdown]
# #### 6. `df` now contains mobility data for your selected country from 2020 and 2021. There are three aggregation levels to this data, namely national (`country_region`), provincial (`sub_region_1`), and city (`sub_region_2`). Separate these data into three different dataframes, namely `df_nation`, `df_province`, and `df_city`.  Print the first 5 lines of each of them.
#
# Hint:
# - For the national data, `sub_region_1` and `sub_region_2` are NaN.
# - For the provincial data, `sub_region_2` is NaN.
# - For the city data, `country_region`, `sub_region_1` and `sub_region_2` are not NaN.
# - Logical operators: <https://realpython.com/python-bitwise-operators/>
# - Use pandas [isna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html) function

# %%
# YOUR CODE HERE

nation   = df['sub_region_1'].isna()  & df['sub_region_2'].isna()  & df['country_region'].notna()
province = df['sub_region_1'].notna() & df['sub_region_2'].isna()  & df['country_region'].notna()
city     = df['sub_region_1'].notna() & df['sub_region_2'].notna() & df['country_region'].notna()

df_nation   = df[nation]
df_province = df[province]
df_city     = df[city]

df_nation.head(5).append(
    df_province.head(5), ignore_index = True).append(
    df_city.head(5), ignore_index = True)
# Out:
#    country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                   NL    Netherlands          NaN          NaN         NaN
# 1                   NL    Netherlands          NaN          NaN         NaN
# 2                   NL    Netherlands          NaN          NaN         NaN
# 3                   NL    Netherlands          NaN          NaN         NaN
# 4                   NL    Netherlands          NaN          NaN         NaN
# 5                   NL    Netherlands      Drenthe          NaN         NaN
# 6                   NL    Netherlands      Drenthe          NaN         NaN
# 7                   NL    Netherlands      Drenthe          NaN         NaN
# 8                   NL    Netherlands      Drenthe          NaN         NaN
# 9                   NL    Netherlands      Drenthe          NaN         NaN
# 10                  NL    Netherlands      Drenthe  Aa en Hunze         NaN
# 11                  NL    Netherlands      Drenthe  Aa en Hunze         NaN
# 12                  NL    Netherlands      Drenthe  Aa en Hunze         NaN
# 13                  NL    Netherlands      Drenthe  Aa en Hunze         NaN
# 14                  NL    Netherlands      Drenthe  Aa en Hunze         NaN
#
#    iso_3166_2_code  census_fips_code                     place_id        date  \
# 0              NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-15
# 1              NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-16
# 2              NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-17
# 3              NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-18
# 4              NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-19
# 5            NL-DR               NaN  ChIJJe9hK-IhyEcRMK4d-ISmq2o  2020-02-15
# 6            NL-DR               NaN  ChIJJe9hK-IhyEcRMK4d-ISmq2o  2020-02-16
# 7            NL-DR               NaN  ChIJJe9hK-IhyEcRMK4d-ISmq2o  2020-02-17
# 8            NL-DR               NaN  ChIJJe9hK-IhyEcRMK4d-ISmq2o  2020-02-18
# 9            NL-DR               NaN  ChIJJe9hK-IhyEcRMK4d-ISmq2o  2020-02-19
# 10             NaN               NaN  ChIJd8Zx3YDYt0cR9DTRc8Z6DIg  2020-02-15
# 11             NaN               NaN  ChIJd8Zx3YDYt0cR9DTRc8Z6DIg  2020-02-16
# 12             NaN               NaN  ChIJd8Zx3YDYt0cR9DTRc8Z6DIg  2020-02-17
# 13             NaN               NaN  ChIJd8Zx3YDYt0cR9DTRc8Z6DIg  2020-02-18
# 14             NaN               NaN  ChIJd8Zx3YDYt0cR9DTRc8Z6DIg  2020-02-19
#
#     retail_and_recreation_percent_change_from_baseline  \
# 0                                                 1.0
# 1                                               -10.0
# 2                                                 0.0
# 3                                                 5.0
# 4                                                 3.0
# 5                                                -6.0
# 6                                               -10.0
# 7                                                 3.0
# 8                                                 8.0
# 9                                                 4.0
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                 1.0
# 1                                                -8.0
# 2                                                -1.0
# 3                                                 4.0
# 4                                                 0.0
# 5                                                 0.0
# 6                                               -10.0
# 7                                                -2.0
# 8                                                 0.0
# 9                                                -4.0
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     parks_percent_change_from_baseline  \
# 0                                 11.0
# 1                                -31.0
# 2                                  8.0
# 3                                 21.0
# 4                                 20.0
# 5                                 18.0
# 6                                -38.0
# 7                                 52.0
# 8                                 45.0
# 9                                 49.0
# 10                                -1.0
# 11                               -36.0
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
#
#     transit_stations_percent_change_from_baseline  \
# 0                                             3.0
# 1                                            -5.0
# 2                                            -3.0
# 3                                            -3.0
# 4                                            -3.0
# 5                                             6.0
# 6                                           -12.0
# 7                                           -24.0
# 8                                           -21.0
# 9                                           -19.0
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
#
#     workplaces_percent_change_from_baseline  \
# 0                                       0.0
# 1                                      -3.0
# 2                                      -5.0
# 3                                      -5.0
# 4                                      -5.0
# 5                                       1.0
# 6                                      -2.0
# 7                                     -22.0
# 8                                     -22.0
# 9                                     -22.0
# 10                                      NaN
# 11                                      NaN
# 12                                    -26.0
# 13                                    -24.0
# 14                                    -23.0
#
#     residential_percent_change_from_baseline
# 0                                        0.0
# 1                                        2.0
# 2                                        1.0
# 3                                        1.0
# 4                                        1.0
# 5                                        0.0
# 6                                        1.0
# 7                                        3.0
# 8                                        3.0
# 9                                        2.0
# 10                                       NaN
# 11                                       NaN
# 12                                       3.0
# 13                                       2.0
# 14                                       1.0

# %% [markdown]
# #### 7. Save `df_nation`, `df_province`, and `df_city` into csv files under folder 'processed_data', and locate this folder under `data_dir`. Name the files `{CC}_nation.csv`, `{CC}_province.csv`, and `{CC}_city.csv`, respectively. `{CC}` stands for your selected country code.

# %%
# creating new directory
new_folder     = 'Processed Data'
directory_name = '%s%s/' % (data_dir, new_folder)
os.mkdir(directory_name)

# %%
# naming files
nation_file   = '%s%s_nation.csv' % (directory_name, country_code)
province_file = '%s%s_province.csv' % (directory_name, country_code)
city_file     = '%s%s_city.csv' % (directory_name, country_code)

# saving files
df_nation.to_csv('%s' % (nation_file))
df_province.to_csv('%s' % (province_file))
df_city.to_csv('%s' % (city_file))

# %% [markdown]
# <hr />

# %% [markdown]
# # PART II - Simple Data Processing

# %% [markdown]
# #### 1. There are multiple activities in the mobility report such as workplaces, parks, transit stations, etc. For each of the activities, what are the average percent changes from baselines for your selected country?

# %%
# YOUR CODE HERE

# only regarding nation-wide: 'df_nation'

# activities:
    # column 1: text
    # column 2: column name

activities = [['retail and recreation',
               'grocery and pharmacy',
               'parks',
               'transit stations',
               'workplaces',
               'residential'],
              ['retail_and_recreation_percent_change_from_baseline',
               'grocery_and_pharmacy_percent_change_from_baseline',
               'parks_percent_change_from_baseline',
               'transit_stations_percent_change_from_baseline',
               'workplaces_percent_change_from_baseline',
               'residential_percent_change_from_baseline']]


for i in range(len(activities[0])):
    # defining mean value
    mean = df_nation['%s' % (activities[1][i])].mean()
    
    # print values
    print('Average change in %s: %.1f%%' % (activities[0][i], mean))
# Out:
# Average change in retail and recreation: -21.0%
# Average change in grocery and pharmacy: -1.1%
# Average change in parks: 75.0%
# Average change in transit stations: -40.8%
# Average change in workplaces: -25.2%
# Average change in residential: 8.4%

# %% [markdown]
# #### 2. Let's look into data from different provinces. How many provinces are there in the data of your selected country? Print all of them.

# %%
# YOUR CODE HERE

provinces = df_province['sub_region_1'].unique()
country   = df_province['country_region'].iloc[0]

print('There are %d provinces in the %s.' % (len(provinces), country))
print('')
print('Provinces:')

for i in range(len(provinces)):
    print(provinces[i])
# Out:
# There are 12 provinces in the Netherlands.
#
# Provinces:
# Drenthe
# Flevoland
# Friesland
# Gelderland
# Groningen
# Limburg
# North Brabant
# North Holland
# Overijssel
# South Holland
# Utrecht
# Zeeland

# %% [markdown]
# #### 3. You can get a summary of each of the provinces using pandas describe function. Using this, find which province experienced the largest (average) changes in workplaces.
#
# Did not understand how to plot describe function per province individually at the same time. Created list of largest average change in an other way. Added Drenthe as example .describe() plot.

# %%
# define dataframe with only workplace changes and provinces
df_wp = df_province[['sub_region_1', 'workplaces_percent_change_from_baseline']]

means = []

print('Avereage change in workplaces per province:')

for i in range(len(provinces)):
    # choose province
    is_province = df_wp['sub_region_1'] == provinces[i]
    
    # find mean and store in means
    mean = df_wp[is_province].mean()[0]
    means.append(mean)
    
    print('%s: %.2f%%' % (provinces[i], mean))
    
    max_mean = 0
    max_province = 'test'
    if abs(mean) > abs(max_mean):
        max_mean = mean
        max_province = provinces[i]

# print larges average change
print('')
print('Largest mean change is: %.2f%% in %s' % (max_mean, max_province))

is_drenthe = df_province['sub_region_1'] == 'Drenthe'
df_province[is_drenthe].describe()
# Out:
# Avereage change in workplaces per province:
# Drenthe: -22.60%
# Flevoland: -26.53%
# Friesland: -21.83%
# Gelderland: -21.25%
# Groningen: -25.41%
# Limburg: -21.72%
# North Brabant: -24.28%
# North Holland: -29.62%
# Overijssel: -22.41%
# South Holland: -26.94%
# Utrecht: -29.81%
# Zeeland: -20.37%
#
# Largest mean change is: -20.37% in Zeeland
#        metro_area  census_fips_code  \
# count         0.0               0.0
# mean          NaN               NaN
# std           NaN               NaN
# min           NaN               NaN
# 25%           NaN               NaN
# 50%           NaN               NaN
# 75%           NaN               NaN
# max           NaN               NaN
#
#        retail_and_recreation_percent_change_from_baseline  \
# count                                         564.000000
# mean                                          -10.418440
# std                                            26.393162
# min                                           -83.000000
# 25%                                           -31.000000
# 50%                                           -10.000000
# 75%                                            10.000000
# max                                            56.000000
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# count                                         565.000000
# mean                                            3.423009
# std                                            14.306046
# min                                           -85.000000
# 25%                                            -3.000000
# 50%                                             3.000000
# 75%                                            12.000000
# max                                            34.000000
#
#        parks_percent_change_from_baseline  \
# count                          532.000000
# mean                           124.605263
# std                            124.768162
# min                            -60.000000
# 25%                             27.000000
# 50%                             83.500000
# 75%                            194.250000
# max                            559.000000
#
#        transit_stations_percent_change_from_baseline  \
# count                                     559.000000
# mean                                      -30.350626
# std                                        18.949247
# min                                       -73.000000
# 25%                                       -41.000000
# 50%                                       -33.000000
# 75%                                       -21.000000
# max                                        53.000000
#
#        workplaces_percent_change_from_baseline  \
# count                               562.000000
# mean                                -22.597865
# std                                  19.245349
# min                                 -83.000000
# 25%                                 -35.000000
# 50%                                 -24.000000
# 75%                                  -5.250000
# max                                  29.000000
#
#        residential_percent_change_from_baseline
# count                                565.000000
# mean                                   6.743363
# std                                    4.538993
# min                                   -3.000000
# 25%                                    4.000000
# 50%                                    7.000000
# 75%                                    9.000000
# max                                   24.000000

# %% [markdown]
# #### 4. Create a new dataframe that only contains data from the province with the largest changes in workplaces, which you found in the previous question.

# %%
# YOUR CODE HERE

is_max_province = df_province['sub_region_1'] == max_province
df_max_province = df_province[is_max_province]

df_max_province.head(5)
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 106281                  NL    Netherlands      Zeeland          NaN
# 106282                  NL    Netherlands      Zeeland          NaN
# 106283                  NL    Netherlands      Zeeland          NaN
# 106284                  NL    Netherlands      Zeeland          NaN
# 106285                  NL    Netherlands      Zeeland          NaN
# ...                    ...            ...          ...          ...
# 195802                  NL    Netherlands      Zeeland          NaN
# 195803                  NL    Netherlands      Zeeland          NaN
# 195804                  NL    Netherlands      Zeeland          NaN
# 195805                  NL    Netherlands      Zeeland          NaN
# 195806                  NL    Netherlands      Zeeland          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 106281         NaN           NL-ZE               NaN
# 106282         NaN           NL-ZE               NaN
# 106283         NaN           NL-ZE               NaN
# 106284         NaN           NL-ZE               NaN
# 106285         NaN           NL-ZE               NaN
# ...            ...             ...               ...
# 195802         NaN           NL-ZE               NaN
# 195803         NaN           NL-ZE               NaN
# 195804         NaN           NL-ZE               NaN
# 195805         NaN           NL-ZE               NaN
# 195806         NaN           NL-ZE               NaN
#
#                            place_id        date  \
# 106281  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-15
# 106282  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-16
# 106283  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-17
# 106284  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-18
# 106285  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-19
# ...                             ...         ...
# 195802  ChIJyfyksadZxEcRt6HidhtRRCo  2021-08-28
# 195803  ChIJyfyksadZxEcRt6HidhtRRCo  2021-08-29
# 195804  ChIJyfyksadZxEcRt6HidhtRRCo  2021-08-30
# 195805  ChIJyfyksadZxEcRt6HidhtRRCo  2021-08-31
# 195806  ChIJyfyksadZxEcRt6HidhtRRCo  2021-09-01
#
#         retail_and_recreation_percent_change_from_baseline  \
# 106281                                                7.0
# 106282                                               -7.0
# 106283                                               -1.0
# 106284                                               10.0
# 106285                                                5.0
# ...                                                   ...
# 195802                                               24.0
# 195803                                               44.0
# 195804                                               69.0
# 195805                                               71.0
# 195806                                               58.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 106281                                                4.0
# 106282                                               -9.0
# 106283                                                3.0
# 106284                                                8.0
# 106285                                                4.0
# ...                                                   ...
# 195802                                               33.0
# 195803                                               42.0
# 195804                                               46.0
# 195805                                               45.0
# 195806                                               46.0
#
#         parks_percent_change_from_baseline  \
# 106281                                17.0
# 106282                               -27.0
# 106283                                20.0
# 106284                                37.0
# 106285                                32.0
# ...                                    ...
# 195802                               272.0
# 195803                               223.0
# 195804                               324.0
# 195805                               378.0
# 195806                               335.0
#
#         transit_stations_percent_change_from_baseline  \
# 106281                                            9.0
# 106282                                           13.0
# 106283                                            0.0
# 106284                                            4.0
# 106285                                            1.0
# ...                                               ...
# 195802                                           14.0
# 195803                                           21.0
# 195804                                           -9.0
# 195805                                            1.0
# 195806                                           -2.0
#
#         workplaces_percent_change_from_baseline  \
# 106281                                      3.0
# 106282                                      0.0
# 106283                                      3.0
# 106284                                      4.0
# 106285                                      4.0
# ...                                         ...
# 195802                                     15.0
# 195803                                     25.0
# 195804                                    -32.0
# 195805                                    -30.0
# 195806                                    -30.0
#
#         residential_percent_change_from_baseline
# 106281                                       0.0
# 106282                                       2.0
# 106283                                       1.0
# 106284                                       0.0
# 106285                                       0.0
# ...                                          ...
# 195802                                       0.0
# 195803                                       0.0
# 195804                                       4.0
# 195805                                       4.0
# 195806                                       3.0
#
# [565 rows x 15 columns]

# %% [markdown]
# #### 5. We're going to look at the changes of this province over time. As you can see, the column date is in string format. Convert this str date column data str to datetime format and append as an extra column called 'date2' to the dataframe.
# Hint: <https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html>

# %%
# YOUR CODE HERE

# convert dates
column_date2 = pandas.to_datetime(df_max_province['date'])

# append column to dataframe
df_max_province = df_max_province.assign(date2 = column_date2.values)

df_max_province
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 106281                  NL    Netherlands      Zeeland          NaN
# 106282                  NL    Netherlands      Zeeland          NaN
# 106283                  NL    Netherlands      Zeeland          NaN
# 106284                  NL    Netherlands      Zeeland          NaN
# 106285                  NL    Netherlands      Zeeland          NaN
# ...                    ...            ...          ...          ...
# 195802                  NL    Netherlands      Zeeland          NaN
# 195803                  NL    Netherlands      Zeeland          NaN
# 195804                  NL    Netherlands      Zeeland          NaN
# 195805                  NL    Netherlands      Zeeland          NaN
# 195806                  NL    Netherlands      Zeeland          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 106281         NaN           NL-ZE               NaN
# 106282         NaN           NL-ZE               NaN
# 106283         NaN           NL-ZE               NaN
# 106284         NaN           NL-ZE               NaN
# 106285         NaN           NL-ZE               NaN
# ...            ...             ...               ...
# 195802         NaN           NL-ZE               NaN
# 195803         NaN           NL-ZE               NaN
# 195804         NaN           NL-ZE               NaN
# 195805         NaN           NL-ZE               NaN
# 195806         NaN           NL-ZE               NaN
#
#                            place_id        date  \
# 106281  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-15
# 106282  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-16
# 106283  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-17
# 106284  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-18
# 106285  ChIJyfyksadZxEcRt6HidhtRRCo  2020-02-19
# ...                             ...         ...
# 195802  ChIJyfyksadZxEcRt6HidhtRRCo  2021-08-28
# 195803  ChIJyfyksadZxEcRt6HidhtRRCo  2021-08-29
# 195804  ChIJyfyksadZxEcRt6HidhtRRCo  2021-08-30
# 195805  ChIJyfyksadZxEcRt6HidhtRRCo  2021-08-31
# 195806  ChIJyfyksadZxEcRt6HidhtRRCo  2021-09-01
#
#         retail_and_recreation_percent_change_from_baseline  \
# 106281                                                7.0
# 106282                                               -7.0
# 106283                                               -1.0
# 106284                                               10.0
# 106285                                                5.0
# ...                                                   ...
# 195802                                               24.0
# 195803                                               44.0
# 195804                                               69.0
# 195805                                               71.0
# 195806                                               58.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 106281                                                4.0
# 106282                                               -9.0
# 106283                                                3.0
# 106284                                                8.0
# 106285                                                4.0
# ...                                                   ...
# 195802                                               33.0
# 195803                                               42.0
# 195804                                               46.0
# 195805                                               45.0
# 195806                                               46.0
#
#         parks_percent_change_from_baseline  \
# 106281                                17.0
# 106282                               -27.0
# 106283                                20.0
# 106284                                37.0
# 106285                                32.0
# ...                                    ...
# 195802                               272.0
# 195803                               223.0
# 195804                               324.0
# 195805                               378.0
# 195806                               335.0
#
#         transit_stations_percent_change_from_baseline  \
# 106281                                            9.0
# 106282                                           13.0
# 106283                                            0.0
# 106284                                            4.0
# 106285                                            1.0
# ...                                               ...
# 195802                                           14.0
# 195803                                           21.0
# 195804                                           -9.0
# 195805                                            1.0
# 195806                                           -2.0
#
#         workplaces_percent_change_from_baseline  \
# 106281                                      3.0
# 106282                                      0.0
# 106283                                      3.0
# 106284                                      4.0
# 106285                                      4.0
# ...                                         ...
# 195802                                     15.0
# 195803                                     25.0
# 195804                                    -32.0
# 195805                                    -30.0
# 195806                                    -30.0
#
#         residential_percent_change_from_baseline      date2
# 106281                                       0.0 2020-02-15
# 106282                                       2.0 2020-02-16
# 106283                                       1.0 2020-02-17
# 106284                                       0.0 2020-02-18
# 106285                                       0.0 2020-02-19
# ...                                          ...        ...
# 195802                                       0.0 2021-08-28
# 195803                                       0.0 2021-08-29
# 195804                                       4.0 2021-08-30
# 195805                                       4.0 2021-08-31
# 195806                                       3.0 2021-09-01
#
# [565 rows x 16 columns]

# %% [markdown]
# #### 6. Sort the data in ascending order of time and save it as 'df_province_largest'

# %%
df_province_largest = df_max_province.sort_values('date2', 
                            ascending = True)


# save file to directory
province_largest_file = '%sdf_province_largest.csv' % directory_name

df_province_largest.to_csv('%s' % (province_largest_file))

# %%
# Execute the cell with the following command to visualize the results
df_province_largest.plot('date', 'workplaces_percent_change_from_baseline')

df_province_largest.resample('7D', on='date2').sum()['workplaces_percent_change_from_baseline'].plot()
# Out:
# <AxesSubplot:xlabel='date2'>

# %% [markdown]
# #### 7. Compare the results above with the results in the google mobility report pdf of your selected province. Discuss the differences and similarities. Please save the mobility report pdf that you use to compare the results with! An example mobility report pdf can be found [here](https://www.gstatic.com/covid19/mobility/2021-09-01_AW_Mobility_Report_en.pdf)
